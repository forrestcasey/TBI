# %%
# Dependencies
import pandas as pd

# %%
# Files to load
TBI_type = "TBI/resources/TBI_data.csv"
TBI_by_year = "TBI/resources/tbi_year.csv"
TBI_by_age = "TBI/resources/tbi_age.csv"

# %%
#Read the gender data file and store in DataFrame
TBI_type_df = pd.read_csv(TBI_type)
TBI_type_df
# Out:
#    Year  Emergency Department Visits  Hospitalizations  Deaths  Total
# 0  2001                        420.6              82.7    18.5  521.0
# 1  2002                        433.9              85.6    18.3  537.2
# 2  2003                        423.3              94.6    18.2  535.4
# 3  2004                        486.3              97.6    18.1  601.3
# 4  2005                        505.0              92.8    18.6  615.7
# 5  2006                        478.9              98.7    18.2  595.1
# 6  2007                        457.5              91.7    18.2  566.7
# 7  2008                        616.4              95.5    17.7  728.9
# 8  2009                        677.4              98.0    17.2  791.9
# 9  2010                        715.7              91.7    17.1  823.7

# %%
#Read the year data file and store in DataFrame
TBI_by_year_df = pd.read_csv(TBI_by_year)
TBI_by_year_df
# Out:
#           injury_mechanism                        type  year  rate_est  \
# 0    Motor vehicle crashes  Emergency Department Visit  2006      85.3
# 1    Motor vehicle crashes  Emergency Department Visit  2007      83.8
# 2    Motor vehicle crashes  Emergency Department Visit  2008      83.9
# 3    Motor vehicle crashes  Emergency Department Visit  2009      88.7
# 4    Motor vehicle crashes  Emergency Department Visit  2010      95.3
# ..                     ...                         ...   ...       ...
# 211                  Total                      Deaths  2010      16.5
# 212                  Total                      Deaths  2011      16.6
# 213                  Total                      Deaths  2012      16.8
# 214                  Total                      Deaths  2013      16.8
# 215                  Total                      Deaths  2014      16.8
#
#      number_est
# 0      254793.0
# 1      252459.0
# 2      254391.0
# 3      270240.0
# 4      292942.0
# ...

# %%
#Read the gender data file and store in DataFrame
TBI_by_age_df = pd.read_csv(TBI_by_age)
TBI_by_age_df
# Out:
#     age_group                        type  \
# 0        0-17  Emergency Department Visit
# 1        0-17  Emergency Department Visit
# 2        0-17  Emergency Department Visit
# 3        0-17  Emergency Department Visit
# 4        0-17  Emergency Department Visit
# ..        ...                         ...
# 226     Total                      Deaths
# 227     Total                      Deaths
# 228     Total                      Deaths
# 229     Total                      Deaths
# 230     Total                      Deaths
#
#                                       injury_mechanism  number_est  rate_est
# 0                                Motor Vehicle Crashes     47138.0      64.1
# 1                                  Unintentional Falls    397190.0     539.8
# 2       Unintentionally struck by or against an object    229236.0     311.6
# 3    Other unintentional injury, mechanism unspecified     55785.0      75.8
# ...
